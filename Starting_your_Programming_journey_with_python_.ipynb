# %% [markdown]
# ![1_Ud_bNdeWPf4iN1EcydaDFA.png](data:image/png;base64,...)

# %%
#My First Program in Python, Yay!!
print("Hello, Students!!")
print("Hello Python!!")
print('Hello world')
# Out:
# Hello, Students!!
# Hello Python!!
# Hello world

# %%
#This is a practice program!
#Hi
print("How are you?")
# Out:
# How are you?

# %% [markdown]
# **Variables and standard data Types**

# %% [markdown]
# ![c-plus-plus-can-not-compare-float-and-int-python-variable-is-variable.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Python-data-structure.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Python_keywords-1024x485.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Python+Variable+Name+Rules.jpg](data:image/jpeg;base64,...)

# %%
False  = 5
print(False)
# Out:
#   File "<ipython-input-40-979ee9f95127>", line 1
#     False  = 5
#               ^
# SyntaxError: can't assign to keyword

# %%
None = 11

# %%
wonder = 2.45
long = "My Height is"
print(wonder+long)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-d1c6ec150451> in <module>()
#       1 wonder = 2.45
#       2 long = "My Height is"
# ----> 3 print(wonder+long)
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %%
wonder = 2.45
long = "My Height is"
print(long,wonder)
# Out:
# My Height is 2.45

# %%
NAME = "panda"
print(NAME)
# Out:
# panda

# %%
#AGE = 15
print("My Age is",#AGE)
# Out:
#   File "<ipython-input-44-8b7964fb08d2>", line 2
#     print("My Age is",#AGE)
#                            ^
# SyntaxError: unexpected EOF while parsing

# %%
23height = 7.29
print(23height)
# Out:
#   File "<ipython-input-45-857d684fc190>", line 1
#     23height = 7.29
#            ^
# SyntaxError: invalid syntax

# %%
_age = 25
print("My Age is",_age)
# Out:
# My Age is 25

# %%
a= False
b = True
print("I am",a)
# Out:
# I am False

# %%
a = 2
 b = 3
print(a,b)
# Out:
#   File "<ipython-input-48-8c324316438b>", line 2
#     b = 3
#     ^
# IndentationError: unexpected indent

# %%
a = 2
b = 3
print(a,b)
# Out:
# 2 3

# %%
a = "Hi! My name is Salman\nI am a Python Programmer!"
print(a)
# Out:
# Hi! My name is Salman
# I am a Python Programmer!

# %%
Students = "The Tech Lab - "
say = "Engineering For Everyone"
Students+say
# Out:
# 'The Tech Lab - Engineering For Everyone'

# %% [markdown]
# *Loops and Data Structures*

# %% [markdown]
# ![images.jfif](data:image/jpeg;base64,...)

# %%
#exits the loop when i is 3
i = 1
while i < 6:
  print(i)
  if i == 3:
    break
  i += 1
# Out:
# 1
# 2
# 3

# %%
i = 1
while i < 6:
  print(i)
  i = i+1
  if i == 3:
    break
# Out:
# 1
# 2

# %%
#print each fruit in the list
fruits = ["apple", "banana", "cherry","pineapple","mango"]
for x in fruits:
  print(x)
# Out:
# apple
# banana
# cherry
# pineapple
# mango

# %%
for x in "banana":
  print(x)
# Out:
# b
# a
# n
# a
# n
# a

# %%
print(fruits[1:3])
# Out:
# ['banana', 'cherry']

# %%
print(fruits[1:])
# Out:
# ['banana', 'cherry', 'pineapple', 'mango']

# %%
print(fruits[-2])
# Out:
# pineapple

# %%
thistuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
print(thistuple[2:5])
# Out:
# ('cherry', 'orange', 'kiwi')

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
print(thisdict["brand"])
# Out:
# Ford

# %%
print(thisdict["year"])
# Out:
# 1964

# %%
thisset = {"apple", "banana", "cherry"}

print("banana" in thisset)
# Out:
# True

# %%
print(thisset[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-34d9ae2adcaa> in <module>()
# ----> 1 print(thisset[1])
#
# TypeError: 'set' object does not support indexing

# %%
print("lemon" in thisset)
# Out:
# False

# %% [markdown]
# **Basic operators and some calculations in Python**

# %% [markdown]
# ![7eced68380a79194167726c69df01c08.jpg](data:image/jpeg;base64,...)

# %%
2+3
# Out:
# 5

# %%
2*3
# Out:
# 6

# %%
a = 10
b=10.2
print(a*b)
# Out:
# 102.0

# %%
2**3
# Out:
# 8

# %%
a/b
# Out:
# 0.9803921568627452

# %%
l = 90
f = 10.2
l/f
# Out:
# 8.823529411764707

# %%
l//f
# Out:
# 8.0

# %%
8%3
# Out:
# 2

# %%
x = 27
y=37.5
z = 93.5
d = 15
y1 = (x+y)*(y+x)+(z*d)
print(y1)
# Out:
# 5562.75

# %% [markdown]
# ![python-operator-precedence.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Decision making in Python with examples**

# %% [markdown]
# ![if-Statements.jpg](data:image/jpeg;base64,...)

# %%
a = 33
b = 200
if b > a:
  print("b is greater than a")

else:
  print("a is greater than b")
# Out:
# b is greater than a

# %%
a = 330
b = 200
if b > a:
  print("b is greater than a")

else:
  print("a is greater than b")
# Out:
# a is greater than b

# %%
a = 33
b = 200
if b > a:
print("b is greater than a")

else:
  print("a is greater than b")
# Out:
#   File "<ipython-input-87-4740eb447739>", line 4
#     print("b is greater than a")
#         ^
# IndentationError: expected an indented block

# %%
a = 33
b = 33
if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b are equal")
# Out:
# a and b are equal

# %%
a = 33
b = 330
if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b are equal")
# Out:
# b is greater than a

# %%
a = 200
b = 33
if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b are equal")
else:
  print("a is greater than b")
# Out:
# a is greater than b

# %%
a = 4
b=10
if a>1 and b>1:
  print("All numbers are greater than 1")
# Out:
# All numbers are greater than 1

# %%
a = 4
b=-10
if a>1 or b>1:
  print("All numbers are greater than 1")
# Out:
# All numbers are greater than 1

# %% [markdown]
# ![i0imk0ay05k21.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Creating Functions in Python**

# %%
def my_testFunction():
  if 2>1:
    print("Yes!")
  
  if 3>5:
    print("No!")

  print("Hello guys!!\nAsk question if you dont understand!")

my_testFunction()
# Out:
# Yes!
# Hello guys!!
# Ask question if you dont understand!

# %% [markdown]
# **Taking Keyboard inputs in Python**

# %%
a = int(input('Please input the number of times you entered Facebook today:'))
print(a)
# Out:
# Please input the number of times you entered Facebook today:8
# 8

# %%
b = float(input('Please input your length in metres:'))
print(b)
# Out:
# Please input your length in metres:2.9
# 2.9

# %%
c = float(input('Please input your width in metres:'))
print(c)
# Out:
# Please input your width in metres:9.2
# 9.2

# %%
Area_of_a_rectangle = b*c
print("Area of the Rectangle is ",Area_of_a_rectangle)
# Out:
# Area of the Rectangle is  26.679999999999996

# %%
d = input('Please input your height in metres:')
print(d)
# Out:
# Please input your height in metres:2
# 2

# %%
type(d)
# Out:
# str

# %%
d*2
# Out:
# '22'

# %% [markdown]
# ![b776dda6d6dc4e72f34ba4f05ba3181c.png](data:image/png;base64,...)

# %% [markdown]
# **Finally! We are at the end of our workshop! Thank you all for your time, patience and understanding :)**
#
# Keep an eye on [The Tech Lab](https://www.facebook.com/thetechlab/) page for future courses on Python and Machine Learning!

# %% [markdown]
# **You can also follow me through my social media links**
# [Facebook](https://www.facebook.com/salmaneunus27/)
# [LinkedIn](https://www.linkedin.com/in/salman-ibne-eunus-09255a144/)
# [Youtube](https://www.youtube.com/channel/UCr3EvjAKPzq1CaQVTyJNtJg?view_as=subscriber)
# [GitHub](https://github.com/SalmanEunus27)
